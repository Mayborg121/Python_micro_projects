# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/master/Restaurant%20-%20Week%201%20Sales.csv")

# %%
df
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
df2 = df.sort_values(by=['Food ID'])

# %%
df_export = df2.to_csv("orders.csv")

# %%
df2.index.name="Order ID"
df2.head()
# Out:
#           Customer ID  Food ID
# Order ID
# 124               909        1
# 35                 77        1
# 45                100        1
# 50                953        1
# 234               646        1

# %%
df=df2

# %%
df
# Out:
#           Customer ID  Food ID
# Order ID
# 124               909        1
# 35                 77        1
# 45                100        1
# 50                953        1
# 234               646        1
# ...               ...      ...
# 153               225       10
# 173               475       10
# 197                51       10
# 68                358       10
# 249               535       10
#
# [250 rows x 2 columns]

# %%
df3 = df.sort_values(by=['Customer ID'])
df3
# Out:
#           Customer ID  Food ID
# Order ID
# 96                  3        2
# 143                10        2
# 31                 20        1
# 101                21        4
# 212                21        4
# ...               ...      ...
# 11                966        5
# 175               968        1
# 209               985        5
# 194               991        2
# 146              1000        2
#
# [250 rows x 2 columns]

# %%
df3 = df.sort_index(axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df3 = df.sort_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:6950, in DataFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    6851 def sort_index(
#    6852     self,
#    6853     *,
#    (...)
#    6862     key: IndexKeyFunc = None,
#    6863 ) -> DataFrame | None:
#    6864     """
#    6865     Sort object by labels (along an axis).
#    6866
#    (...)
#    6948     d  4
#    6949     """
# -> 6950     return super().sort_index(
#    6951         axis=axis,
#    6952         level=level,
#    6953         ascending=ascending,
#    6954         inplace=inplace,
#    6955         kind=kind,
#    6956         na_position=na_position,
#    6957         sort_remaining=sort_remaining,
# ...
