# %% [markdown]
# ## Pandas Library :
# #### -- Pandas is python library used for work
# #### -- it has functions for anlysing,cleaning, exploring and manipulating the data
# #### -- "Pandas" stands for python-datascience . it s full form is "panel data" and "python data analysis"
# #### -- it was created by Wes Mckinney in 2008.
# #### -- pandas allows us to analyze big data and make conclusions based on statistical theories.
# #### -- pandas can clean messy datasets and make them readable and relevent.
# #### -- relevent data is very important in data engineering.
#
# ## Advantages of using Pandas :
# #### -- Fast and efficient for manipulating and analyzing the data.
# #### -- data from differnt objects can be loaded .
# #### -- easy handling of missing data .
# #### -- size mutability.
# #### -- data merging and joining.
# #### -- Flexible reshaping of data.

# %% [markdown]
# ## Data types :
# --

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\MAYBORG\\Downloads\\archive\Highest Holywood Grossing Movies.csv")
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Star Wars: Episode VII - The Force Awakens (2015)
# 1             1                           Avengers: Endgame (2019)
# 2             2                                      Avatar (2009)
# 3             3                               Black Panther (2018)
# 4             4                      Avengers: Infinity War (2018)
# ..          ...                                                ...
# 913         913                                The Notebook (2004)
# 914         914                   Jimmy Neutron: Boy Genius (2001)
# 915         915                               Eat Pray Love (2010)
# 916         916                 The Texas Chainsaw Massacre (2003)
# 917         917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# ...

# %%
df1 = df[["Title","Release Date","World Sales (in $)","Genre"]][0:20]
df1
# Out:
#                                                 Title       Release Date  \
# 0   Star Wars: Episode VII - The Force Awakens (2015)  December 16, 2015
# 1                            Avengers: Endgame (2019)     April 24, 2019
# 2                                       Avatar (2009)  December 16, 2009
# 3                                Black Panther (2018)                NaN
# 4                       Avengers: Infinity War (2018)                NaN
# 5                      Spider-Man: No Way Home (2021)                NaN
# 6                                      Titanic (1997)  December 19, 1997
# 7                               Jurassic World (2015)      June 10, 2015
# 8                                 The Avengers (2012)     April 25, 2012
# 9      Star Wars: Episode VIII - The Last Jedi (2017)  December 13, 2017
# 10                               Incredibles 2 (2018)                NaN
# 11                               The Lion King (2019)      July 11, 2019
# ...
